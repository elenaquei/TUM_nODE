# %% [markdown]
# # Antisymmetric nODE with perturbation
#
# the goal of this code is to train a nODE with right hand side
#      $$\tanh( \hat W x + b)$$
# with
#     $$\hat W = W - W^T + \epsilon P + \gamma I,   $$
# where the norm of P is small

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
import matplotlib.pyplot as plt
import numpy as np

# Juptyer magic: For export. Makes the plots size right for the screen 
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %config InlineBackend.figure_formats = ['svg'] 


torch.backends.cudnn.deterministic = True
seed = np.random.randint(1,200)
# seed = 56
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
print(seed)
g = torch.Generator()
g.manual_seed(seed)
# Out:
# 120

# %% [markdown]
# # Data preparation

# %%
data_noise = 0.15
plotlim = [-3, 3]
subfolder = 'traj_moons'


from models.training import create_dataloader
dataloader, dataloader_viz = create_dataloader('moons', noise = data_noise, plotlim = plotlim, random_state = seed)

# %% [markdown]
# ## Training and generating level sets

# %%
from models.neural_odes import convolutionalNeuralODE

hidden_dim = 10
data_dim = 2 
augment_dim = 0

num_epochs = 80 #number of optimization runs in which the dataset is used for gradient decent
eps = 0.2
output_dim = 2

#T is the end time of the neural ODE evolution, num_steps are the amount of discretization steps for the ODE solver
T, num_steps = 1, 1
bound = 0.
fp = False 
cross_entropy = True
turnpike = False

non_linearity = 'tanh' #'relu' #
architecture =  'outside' # 'inside' # 

torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
cnode = convolutionalNeuralODE(device, data_dim, hidden_dim, output_dim, non_linearity=non_linearity, 
                    architecture=architecture, T=T, time_steps=num_steps)

optimizer_cnode = torch.optim.Adam(cnode.parameters(), lr=1e-3)

# %%
from models.training import convolutionalTrainer

trainer_cnode = convolutionalTrainer(cnode, optimizer_cnode, device, cross_entropy=cross_entropy,
                        verbose = True, antisymm_diag = .03) 
trainer_cnode.train(dataloader, num_epochs)
# Out:
# Epoch 0/38
# Loss: 0.846
# Increased loss for antisymmetry:  3.107
#
# Epoch 10/38
# Loss: 0.800
# Increased loss for antisymmetry:  2.936
#
# Epoch 20/38
# Loss: 0.752
# Increased loss for antisymmetry:  2.770
#
# Epoch 30/38
# Loss: 0.655
# Increased loss for antisymmetry:  2.611
# Epoch 1: 0.716
#
# Epoch 0/38
# Loss: 0.625
# Increased loss for antisymmetry:  2.488
#
# Epoch 10/38
# Loss: 0.555
# Increased loss for antisymmetry:  2.337
#
# Epoch 20/38
# Loss: 0.519
# Increased loss for antisymmetry:  2.191
#
# Epoch 30/38
# Loss: 0.457
# Increased loss for antisymmetry:  2.049
# Epoch 2: 0.546
#
# Epoch 0/38
# Loss: 0.498
# Increased loss for antisymmetry:  1.938
#
# Epoch 10/38
# Loss: 0.504
# Increased loss for antisymmetry:  1.802
#
# Epoch 20/38
# Loss: 0.439
# Increased loss for antisymmetry:  1.668
#
# Epoch 30/38
# Loss: 0.380
# Increased loss for antisymmetry:  1.538
# Epoch 3: 0.429
#
# Epoch 0/38
# Loss: 0.299
# Increased loss for antisymmetry:  1.436
#
# Epoch 10/38
# Loss: 0.383
# Increased loss for antisymmetry:  1.312
#
# Epoch 20/38
# Loss: 0.364
# Increased loss for antisymmetry:  1.191
#
# Epoch 30/38
# Loss: 0.389
# Increased loss for antisymmetry:  1.073
# Epoch 4: 0.361
#
# Epoch 0/38
# Loss: 0.320
# Increased loss for antisymmetry:  0.981
#
# Epoch 10/38
# Loss: 0.242
# Increased loss for antisymmetry:  0.868
#
# Epoch 20/38
# Loss: 0.374
# Increased loss for antisymmetry:  0.759
#
# Epoch 30/38
# Loss: 0.348
# Increased loss for antisymmetry:  0.653
# Epoch 5: 0.323
#
# Epoch 0/38
# Loss: 0.326
# Increased loss for antisymmetry:  0.571
#
# Epoch 10/38
# Loss: 0.253
# Increased loss for antisymmetry:  0.472
#
# Epoch 20/38
# Loss: 0.287
# Increased loss for antisymmetry:  0.377
#
# Epoch 30/38
# Loss: 0.316
# Increased loss for antisymmetry:  0.286
# Epoch 6: 0.301
#
# Epoch 0/38
# Loss: 0.249
# Increased loss for antisymmetry:  0.218
#
# Epoch 10/38
# Loss: 0.269
# Increased loss for antisymmetry:  0.139
#
# Epoch 20/38
# Loss: 0.193
# Increased loss for antisymmetry:  0.103
#
# Epoch 30/38
# Loss: 0.336
# Increased loss for antisymmetry:  0.082
# Epoch 7: 0.288
#
# Epoch 0/38
# Loss: 0.218
# Increased loss for antisymmetry:  0.070
#
# Epoch 10/38
# Loss: 0.313
# Increased loss for antisymmetry:  0.052
#
# Epoch 20/38
# Loss: 0.286
# Increased loss for antisymmetry:  0.036
#
# Epoch 30/38
# Loss: 0.228
# Increased loss for antisymmetry:  0.023
# Epoch 8: 0.282
#
# Epoch 0/38
# Loss: 0.272
# Increased loss for antisymmetry:  0.012
#
# Epoch 10/38
# Loss: 0.318
# Increased loss for antisymmetry:  0.004
#
# Epoch 20/38
# Loss: 0.221
# Increased loss for antisymmetry:  0.004
#
# Epoch 30/38
# Loss: 0.274
# Increased loss for antisymmetry:  0.003
# Epoch 9: 0.277
#
# Epoch 0/38
# Loss: 0.122
# Increased loss for antisymmetry:  0.003
#
# Epoch 10/38
# Loss: 0.228
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.313
# Increased loss for antisymmetry:  0.002
#
# Epoch 30/38
# Loss: 0.296
# Increased loss for antisymmetry:  0.001
# Epoch 10: 0.278
#
# Epoch 0/38
# Loss: 0.350
# Increased loss for antisymmetry:  0.002
#
# Epoch 10/38
# Loss: 0.348
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.184
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.320
# Increased loss for antisymmetry:  0.001
# Epoch 11: 0.275
#
# Epoch 0/38
# Loss: 0.296
# Increased loss for antisymmetry:  0.002
#
# Epoch 10/38
# Loss: 0.287
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.319
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.290
# Increased loss for antisymmetry:  0.001
# Epoch 12: 0.275
#
# Epoch 0/38
# Loss: 0.244
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.243
# Increased loss for antisymmetry:  0.002
#
# Epoch 20/38
# Loss: 0.376
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.228
# Increased loss for antisymmetry:  0.001
# Epoch 13: 0.275
#
# Epoch 0/38
# Loss: 0.306
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.332
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.204
# Increased loss for antisymmetry:  0.002
#
# Epoch 30/38
# Loss: 0.307
# Increased loss for antisymmetry:  0.002
# Epoch 14: 0.276
#
# Epoch 0/38
# Loss: 0.277
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.293
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.298
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.323
# Increased loss for antisymmetry:  0.001
# Epoch 15: 0.274
#
# Epoch 0/38
# Loss: 0.302
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.207
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.276
# Increased loss for antisymmetry:  0.002
#
# Epoch 30/38
# Loss: 0.430
# Increased loss for antisymmetry:  0.001
# Epoch 16: 0.274
#
# Epoch 0/38
# Loss: 0.291
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.355
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.235
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.389
# Increased loss for antisymmetry:  0.001
# Epoch 17: 0.274
#
# Epoch 0/38
# Loss: 0.302
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.245
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.221
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.340
# Increased loss for antisymmetry:  0.001
# Epoch 18: 0.274
#
# Epoch 0/38
# Loss: 0.342
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.325
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.206
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.256
# Increased loss for antisymmetry:  0.001
# Epoch 19: 0.275
#
# Epoch 0/38
# Loss: 0.234
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.193
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.248
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.183
# Increased loss for antisymmetry:  0.002
# Epoch 20: 0.276
#
# Epoch 0/38
# Loss: 0.228
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.335
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.190
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.329
# Increased loss for antisymmetry:  0.002
# Epoch 21: 0.276
#
# Epoch 0/38
# Loss: 0.356
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.219
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.331
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.218
# Increased loss for antisymmetry:  0.001
# Epoch 22: 0.276
#
# Epoch 0/38
# Loss: 0.224
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.108
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.337
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.236
# Increased loss for antisymmetry:  0.002
# Epoch 23: 0.275
#
# Epoch 0/38
# Loss: 0.248
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.365
# Increased loss for antisymmetry:  0.002
#
# Epoch 20/38
# Loss: 0.221
# Increased loss for antisymmetry:  0.002
#
# Epoch 30/38
# Loss: 0.297
# Increased loss for antisymmetry:  0.001
# Epoch 24: 0.274
#
# Epoch 0/38
# Loss: 0.278
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.238
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.340
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.263
# Increased loss for antisymmetry:  0.001
# Epoch 25: 0.274
#
# Epoch 0/38
# Loss: 0.196
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.265
# Increased loss for antisymmetry:  0.002
#
# Epoch 20/38
# Loss: 0.225
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.297
# Increased loss for antisymmetry:  0.001
# Epoch 26: 0.273
#
# Epoch 0/38
# Loss: 0.267
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.337
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.139
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.312
# Increased loss for antisymmetry:  0.001
# Epoch 27: 0.277
#
# Epoch 0/38
# Loss: 0.308
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.250
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.263
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.302
# Increased loss for antisymmetry:  0.001
# Epoch 28: 0.275
#
# Epoch 0/38
# Loss: 0.253
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.309
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.172
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.259
# Increased loss for antisymmetry:  0.001
# Epoch 29: 0.274
#
# Epoch 0/38
# Loss: 0.328
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.365
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.331
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.187
# Increased loss for antisymmetry:  0.001
# Epoch 30: 0.272
#
# Epoch 0/38
# Loss: 0.319
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.321
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.186
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.329
# Increased loss for antisymmetry:  0.001
# Epoch 31: 0.274
#
# Epoch 0/38
# Loss: 0.190
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.277
# Increased loss for antisymmetry:  0.002
#
# Epoch 20/38
# Loss: 0.177
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.216
# Increased loss for antisymmetry:  0.001
# Epoch 32: 0.274
#
# Epoch 0/38
# Loss: 0.276
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.297
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.253
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.397
# Increased loss for antisymmetry:  0.001
# Epoch 33: 0.272
#
# Epoch 0/38
# Loss: 0.282
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.290
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.208
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.376
# Increased loss for antisymmetry:  0.001
# Epoch 34: 0.276
#
# Epoch 0/38
# Loss: 0.305
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.266
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.216
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.235
# Increased loss for antisymmetry:  0.001
# Epoch 35: 0.273
#
# Epoch 0/38
# Loss: 0.189
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.366
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.233
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.356
# Increased loss for antisymmetry:  0.001
# Epoch 36: 0.276
#
# Epoch 0/38
# Loss: 0.164
# Increased loss for antisymmetry:  0.002
#
# Epoch 10/38
# Loss: 0.180
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.243
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.238
# Increased loss for antisymmetry:  0.001
# Epoch 37: 0.274
#
# Epoch 0/38
# Loss: 0.251
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.202
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.202
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.306
# Increased loss for antisymmetry:  0.001
# Epoch 38: 0.274
#
# Epoch 0/38
# Loss: 0.223
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.258
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.247
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.191
# Increased loss for antisymmetry:  0.001
# Epoch 39: 0.274
#
# Epoch 0/38
# Loss: 0.236
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.363
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.274
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.374
# Increased loss for antisymmetry:  0.001
# Epoch 40: 0.272
#
# Epoch 0/38
# Loss: 0.199
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.173
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.227
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.186
# Increased loss for antisymmetry:  0.001
# Epoch 41: 0.274
#
# Epoch 0/38
# Loss: 0.307
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.218
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.183
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.341
# Increased loss for antisymmetry:  0.001
# Epoch 42: 0.275
#
# Epoch 0/38
# Loss: 0.235
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.292
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.222
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.220
# Increased loss for antisymmetry:  0.001
# Epoch 43: 0.273
#
# Epoch 0/38
# Loss: 0.406
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.225
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.224
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.259
# Increased loss for antisymmetry:  0.001
# Epoch 44: 0.273
#
# Epoch 0/38
# Loss: 0.217
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.248
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.299
# Increased loss for antisymmetry:  0.002
#
# Epoch 30/38
# Loss: 0.302
# Increased loss for antisymmetry:  0.001
# Epoch 45: 0.272
#
# Epoch 0/38
# Loss: 0.279
# Increased loss for antisymmetry:  0.002
#
# Epoch 10/38
# Loss: 0.175
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.182
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.243
# Increased loss for antisymmetry:  0.002
# Epoch 46: 0.274
#
# Epoch 0/38
# Loss: 0.148
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.307
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.358
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.307
# Increased loss for antisymmetry:  0.001
# Epoch 47: 0.273
#
# Epoch 0/38
# Loss: 0.269
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.356
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.247
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.227
# Increased loss for antisymmetry:  0.001
# Epoch 48: 0.274
#
# Epoch 0/38
# Loss: 0.384
# Increased loss for antisymmetry:  0.002
#
# Epoch 10/38
# Loss: 0.329
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.212
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.145
# Increased loss for antisymmetry:  0.001
# Epoch 49: 0.275
#
# Epoch 0/38
# Loss: 0.297
# Increased loss for antisymmetry:  0.002
#
# Epoch 10/38
# Loss: 0.256
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.348
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.342
# Increased loss for antisymmetry:  0.001
# Epoch 50: 0.274
#
# Epoch 0/38
# Loss: 0.169
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.381
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.316
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.255
# Increased loss for antisymmetry:  0.001
# Epoch 51: 0.273
#
# Epoch 0/38
# Loss: 0.278
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.325
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.231
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.346
# Increased loss for antisymmetry:  0.001
# Epoch 52: 0.273
#
# Epoch 0/38
# Loss: 0.253
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.332
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.288
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.227
# Increased loss for antisymmetry:  0.001
# Epoch 53: 0.274
#
# Epoch 0/38
# Loss: 0.215
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.201
# Increased loss for antisymmetry:  0.002
#
# Epoch 20/38
# Loss: 0.295
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.356
# Increased loss for antisymmetry:  0.001
# Epoch 54: 0.272
#
# Epoch 0/38
# Loss: 0.241
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.232
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.347
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.261
# Increased loss for antisymmetry:  0.001
# Epoch 55: 0.273
#
# Epoch 0/38
# Loss: 0.312
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.346
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.265
# Increased loss for antisymmetry:  0.002
#
# Epoch 30/38
# Loss: 0.227
# Increased loss for antisymmetry:  0.001
# Epoch 56: 0.273
#
# Epoch 0/38
# Loss: 0.156
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.227
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.289
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.264
# Increased loss for antisymmetry:  0.001
# Epoch 57: 0.272
#
# Epoch 0/38
# Loss: 0.307
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.253
# Increased loss for antisymmetry:  0.002
#
# Epoch 20/38
# Loss: 0.124
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.269
# Increased loss for antisymmetry:  0.001
# Epoch 58: 0.275
#
# Epoch 0/38
# Loss: 0.214
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.186
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.233
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.247
# Increased loss for antisymmetry:  0.001
# Epoch 59: 0.272
#
# Epoch 0/38
# Loss: 0.265
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.182
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.425
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.171
# Increased loss for antisymmetry:  0.001
# Epoch 60: 0.272
#
# Epoch 0/38
# Loss: 0.376
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.228
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.188
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.288
# Increased loss for antisymmetry:  0.001
# Epoch 61: 0.275
#
# Epoch 0/38
# Loss: 0.296
# Increased loss for antisymmetry:  0.002
#
# Epoch 10/38
# Loss: 0.300
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.231
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.344
# Increased loss for antisymmetry:  0.002
# Epoch 62: 0.275
#
# Epoch 0/38
# Loss: 0.230
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.399
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.203
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.423
# Increased loss for antisymmetry:  0.001
# Epoch 63: 0.273
#
# Epoch 0/38
# Loss: 0.265
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.360
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.270
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.328
# Increased loss for antisymmetry:  0.001
# Epoch 64: 0.274
#
# Epoch 0/38
# Loss: 0.265
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.271
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.328
# Increased loss for antisymmetry:  0.002
#
# Epoch 30/38
# Loss: 0.322
# Increased loss for antisymmetry:  0.001
# Epoch 65: 0.275
#
# Epoch 0/38
# Loss: 0.352
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.303
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.333
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.174
# Increased loss for antisymmetry:  0.001
# Epoch 66: 0.272
#
# Epoch 0/38
# Loss: 0.387
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.262
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.231
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.133
# Increased loss for antisymmetry:  0.001
# Epoch 67: 0.273
#
# Epoch 0/38
# Loss: 0.236
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.257
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.273
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.358
# Increased loss for antisymmetry:  0.001
# Epoch 68: 0.274
#
# Epoch 0/38
# Loss: 0.441
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.255
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.136
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.210
# Increased loss for antisymmetry:  0.001
# Epoch 69: 0.273
#
# Epoch 0/38
# Loss: 0.347
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.327
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.247
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.284
# Increased loss for antisymmetry:  0.002
# Epoch 70: 0.272
#
# Epoch 0/38
# Loss: 0.220
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.189
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.241
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.227
# Increased loss for antisymmetry:  0.001
# Epoch 71: 0.274
#
# Epoch 0/38
# Loss: 0.226
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.229
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.296
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.200
# Increased loss for antisymmetry:  0.001
# Epoch 72: 0.274
#
# Epoch 0/38
# Loss: 0.260
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.257
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.417
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.227
# Increased loss for antisymmetry:  0.001
# Epoch 73: 0.273
#
# Epoch 0/38
# Loss: 0.209
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.273
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.243
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.278
# Increased loss for antisymmetry:  0.001
# Epoch 74: 0.273
#
# Epoch 0/38
# Loss: 0.261
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.274
# Increased loss for antisymmetry:  0.002
#
# Epoch 20/38
# Loss: 0.248
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.202
# Increased loss for antisymmetry:  0.001
# Epoch 75: 0.272
#
# Epoch 0/38
# Loss: 0.278
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.249
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.278
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.298
# Increased loss for antisymmetry:  0.001
# Epoch 76: 0.271
#
# Epoch 0/38
# Loss: 0.242
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.381
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.226
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.189
# Increased loss for antisymmetry:  0.001
# Epoch 77: 0.272
#
# Epoch 0/38
# Loss: 0.229
# Increased loss for antisymmetry:  0.002
#
# Epoch 10/38
# Loss: 0.270
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.323
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.260
# Increased loss for antisymmetry:  0.001
# Epoch 78: 0.271
#
# Epoch 0/38
# Loss: 0.298
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.208
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.227
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.348
# Increased loss for antisymmetry:  0.001
# Epoch 79: 0.271
#
# Epoch 0/38
# Loss: 0.378
# Increased loss for antisymmetry:  0.001
#
# Epoch 10/38
# Loss: 0.264
# Increased loss for antisymmetry:  0.001
#
# Epoch 20/38
# Loss: 0.224
# Increased loss for antisymmetry:  0.001
#
# Epoch 30/38
# Loss: 0.231
# Increased loss for antisymmetry:  0.001
# Epoch 80: 0.271

# %%
from plots.plots import classification_levelsets
classification_levelsets(cnode)
plt.plot(trainer_cnode.histories['epoch_loss_history'])
plt.xlim(0, len(trainer_cnode.histories['epoch_loss_history']) - 1)
plt.ylim(0)
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.show()
# Out:
# /Users/queirolo/.local/share/virtualenvs/TUM_nODE-bBJE3WN-/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
from scipy.io import savemat

W = cnode.flow.dynamics.fc2_time[0].weight.detach().numpy()
b = cnode.flow.dynamics.fc2_time[0].bias.detach().numpy()

#print(W,b)
dic = {"W" : W, "b" : b}
savemat("coefs_convolutionalNode.mat", dic)
